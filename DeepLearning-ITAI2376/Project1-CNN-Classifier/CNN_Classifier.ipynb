# %% [markdown]
# # L05 Chihuahua vs Muffin Workshop With CNN
# **Student Name:** Denis Aosa
# **Course:** ITAI 1378
#
# This notebook upgrades the previous Dense architecture into a Convolutional Neural Network (CNN) architecture with data augmentation.

# %%
# !git clone https://github.com/patitimoner/workshop-chihuahua-vs-muffin.git
# %cd workshop-chihuahua-vs-muffin
# !ls
# Out:
# [WinError 2] The system cannot find the file specified: 'workshop-chihuahua-vs-muffin'
# C:\Users\denis.aosa\.gemini\antigravity\playground\vector-perihelion
# 'git' is not recognized as an internal or external command,
# operable program or batch file.
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import numpy as np

print("Tensorflow version:", tf.__version__)
# Out:
# ------------------------------
# ModuleNotFoundErrorTraceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import tensorflow as tf
#       2 from tensorflow.keras import layers, models
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
img_height, img_width = 150, 150

data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal", input_shape=(img_height, img_width, 3)),
  layers.RandomRotation(0.1),
  layers.RandomZoom(0.1),
])
# Out:
# ------------------------------
# NameErrorTraceback (most recent call last)
# Cell In[3], line 3
#       1 img_height, img_width = 150, 150
# ----> 3 data_augmentation = tf.keras.Sequential([
#       4   layers.RandomFlip("horizontal", input_shape=(img_height, img_width, 3)),
#       5   layers.RandomRotation(0.1),
#       6   layers.RandomZoom(0.1),
#       7 ])
#
# NameError: name 'tf' is not defined

# %%
model = models.Sequential([
  data_augmentation,
  layers.Rescaling(1./255),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(128, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# ------------------------------
# NameErrorTraceback (most recent call last)
# Cell In[4], line 1
# ----> 1 model = models.Sequential([
#       2   data_augmentation,
#       3   layers.Rescaling(1./255),
#       4   layers.Conv2D(32, 3, padding='same', activation='relu'),
#       5   layers.MaxPooling2D(),
#       6   layers.Conv2D(64, 3, padding='same', activation='relu'),
#       7   layers.MaxPooling2D(),
#       8   layers.Conv2D(128, 3, padding='same', activation='relu'),
#       9   layers.MaxPooling2D(),
#      10   layers.Dropout(0.2),
#      11   layers.Flatten(),
#      12   layers.Dense(128, activation='relu'),
#      13   layers.Dense(1, activation='sigmoid')
#      14 ])
#      16 model.compile(optimizer='adam',
#      17               loss='binary_crossentropy',
#      18               metrics=['accuracy'])
#      20 model.summary()
#
# NameError: name 'models' is not defined
